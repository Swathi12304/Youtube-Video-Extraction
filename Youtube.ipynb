# %% [markdown]
# <a href="https://colab.research.google.com/github/Swathi12304/Youtube-Video-Extraction/blob/main/Youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !pip install youtube-dl
# Out:
# ...
#      |████████████████████████████████| 1.9 MB 8.3 MB/s
# ...

# %%
#another one pytube

# %%
import urllib.request
import re 
import cv2
from PIL import Image #when working with images
import os #to access the files
import glob #access the files inside the directorry
import pandas as pd 
import youtube_dl #when accessing the youtube to strea, and download
from glob import glob
import numpy as np

# %%
video_lnk = []
search_keyword = input("Enter the keyword:")
html = urllib.request.urlopen("https://www.youtube.com/results?search_query="+ search_keyword+"&sp=CAMSBggFEAEYAQ%253D%253D")
video_ids = re.findall(r"watch\?v=(\S{11})", html.read().decode())
video_ids = video_ids[0:4]

for vid in video_ids:
  video_lnk.append(f"https://www.youtube.com/watch?v="+ vid)

for i in range(len(video_lnk)):
  url = video_lnk[i]
  print(url)
  with youtube_dl.YoutubeDL({'format':'bestvideo[ext=mp4]+bestaudio[ext=m4a]/best[ext=mp4]/best'}) as ydl:
    ydl.download([url])
  print("successfully")
  i+=1
  if i>=4:
    break
# Out:
# Enter the keyword:logitech+ads
# https://www.youtube.com/watch?v=Z9pzYK3Mx8E
# [youtube] Z9pzYK3Mx8E: Downloading webpage
# [download] Logitech MX Keys Mini - Minimalist keyboard for creators-Z9pzYK3Mx8E.mp4 has already been downloaded and merged
# successfully
# https://www.youtube.com/watch?v=V-0E9KDtoGQ
# [youtube] V-0E9KDtoGQ: Downloading webpage
# [youtube] V-0E9KDtoGQ: Downloading MPD manifest
# [download] Lil Nas X Featuring in Logitech SuperBowl Commercial 2021 Ad-V-0E9KDtoGQ.mp4 has already been downloaded and merged
# successfully
# https://www.youtube.com/watch?v=Nbdp_O0vBm4
# [youtube] Nbdp_O0vBm4: Downloading webpage
# [download] Logitech KDA Limited Edition BUNDLE _ ADS  COMMERCIAL VIDEO-Nbdp_O0vBm4.mp4 has already been downloaded and merged
# successfully
# https://www.youtube.com/watch?v=JZyAQK_Mt5U
# [youtube] JZyAQK_Mt5U: Downloading webpage
# [youtube] JZyAQK_Mt5U: Downloading MPD manifest
# [dashsegments] Total fragments: 8
# ...

# %%
# !pip install opencv-python

# %%
path = glob("/content/drive/MyDrive/Colab Notebooks/*.mp4")
i = 1
for file in path:
  src = file
  dst = "change"+str(i)+".mp4"
  os.rename(src,dst)
  i+=1

# %%
import cv2

# %%
cam = cv2.VideoCapture("/content/drive/MyDrive/Colab Notebooks/change1.mp4")

# %%
currentframe = 0

# %%
while(True):
  ret,frame = cam.read()
  if ret:
    name = '/content/drive/MyDrive/Colab Notebooks/Folder1/frame' + str(currentframe) + '.jpg'
    print('Creating....' + name)

    cv2.imwrite(name,frame)
    currentframe += 1
  else:
    break
cam.release()
cv2.destroyAllWindows()
# Out:
# Creating..../content/drive/MyDrive/Colab Notebooks/Folder1/frame0.jpg
# Creating..../content/drive/MyDrive/Colab Notebooks/Folder1/frame1.jpg
# Creating..../content/drive/MyDrive/Colab Notebooks/Folder1/frame2.jpg
# Creating..../content/drive/MyDrive/Colab Notebooks/Folder1/frame3.jpg
# Creating..../content/drive/MyDrive/Colab Notebooks/Folder1/frame4.jpg
# Creating..../content/drive/MyDrive/Colab Notebooks/Folder1/frame5.jpg
# Creating..../content/drive/MyDrive/Colab Notebooks/Folder1/frame6.jpg
# Creating..../content/drive/MyDrive/Colab Notebooks/Folder1/frame7.jpg
# Creating..../content/drive/MyDrive/Colab Notebooks/Folder1/frame8.jpg
# Creating..../content/drive/MyDrive/Colab Notebooks/Folder1/frame9.jpg
# Creating..../content/drive/MyDrive/Colab Notebooks/Folder1/frame10.jpg
# Creating..../content/drive/MyDrive/Colab Notebooks/Folder1/frame11.jpg
# Creating..../content/drive/MyDrive/Colab Notebooks/Folder1/frame12.jpg
# ...

# %%
#Generating Frames

def create_dir(path):
  try:
    if not os.path.exists(path):
      os.makedirs(path)
  except OSError:
    print(f"ERROR: Creaitng directory with name {path}")

def save_frame(video_path, save_dir):
  name = video_path.split("/")[-1].split(".")[0]
  save_path = os.path.join(save_dir,name)
  print(name)
  create_dir(save_path)
  
  cap = cv2.VideoCapture(video_path)
  idx = 0
  while True:
    ret, frame = cap.read()
    if ret == False:
      cap.release()
      break
    cv2.imwrite(f"{save_path}/{idx}.jpg", frame)
    idx+=1
if __name__=="__main__":
  video_paths = glob(r"/content/drive/MyDrive/Colab Notebooks/*.mp4")
  save_dir = "save"

  for path in video_paths:
    save_frame(path,save_dir)
# Out:
# change1
# change2
# change3
# change4
# change5

# %%
video_paths
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/change1.mp4',
#  '/content/drive/MyDrive/Colab Notebooks/change2.mp4',
#  '/content/drive/MyDrive/Colab Notebooks/change3.mp4',
#  '/content/drive/MyDrive/Colab Notebooks/change4.mp4',
#  '/content/drive/MyDrive/Colab Notebooks/change5.mp4']
